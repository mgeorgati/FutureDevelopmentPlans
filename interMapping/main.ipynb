# %%
from IPython.core.display import display, HTML
# Import the folium library
import folium

# Build the default map for a specific location
map = folium.Map(location=[43.61092, 3.87723])
map1 = folium.Map(location=[55, 12])
htmlmap = HTML('<iframe srcdoc="{0}" style="float:left; width: {1}px; height: {2}px; display:inline-block; width: 50%; margin: 0 auto; border: 2px solid black"></iframe>'
           '<iframe srcdoc="{3}" style="float:right; width: {4}px; height: {5}px; display:inline-block; width: 50%; margin: 0 auto; border: 2px solid black"></iframe>'
           .format(map.get_root().render().replace('"', '&quot;'),500,500,
                   map1.get_root().render().replace('"', '&quot;'),500,500))
html = htmlmap.data
with open('html_file.html', 'w') as f:
    f.write(html)

# %%
htmlwhole = """<!DOCTYPE html>
<html>

<head>
    <title>Parking garages in Copenhagen</title>
    <meta charset="utf-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0">

    <link rel="shortcut icon" type="image/x-icon" href="docs/images/favicon.ico" />

    <link rel="stylesheet" href="https://unpkg.com/leaflet@1.9.3/dist/leaflet.css" integrity="sha256-kLaT2GOSpHechhsozzB+flnD+zUyjE2LlfWPgU04xyI=" crossorigin="" />
    <script src="https://unpkg.com/leaflet@1.9.3/dist/leaflet.js" integrity="sha256-WBkoXOwTeyKclOHuWtc+i2uENFpDZ9YPdf5Hf+D7ewM=" crossorigin=""></script>

    <script src="https://code.jquery.com/jquery-3.6.3.min.js"></script>

    <style>
        html,
        body {
            height: 100%;
            margin: 0;
        }
        
        body {
            padding: 0;
            margin: 0;
        }
        
        #map {
            height: 100%;
            width: 100vw;
        }
    </style>
</head>

<body>
    <div id='map'></div>
    <script>

        var map = L.map('map').setView([55.675706, 12.578745], 14).on('click', onMapClick);

        L.tileLayer('https://api.mapbox.com/styles/v1/{id}/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoibWFwYm94IiwiYSI6ImNpejY4NXVycTA2emYycXBndHRqcmZ3N3gifQ.rJcFIG214AriISLbB6B5aw', {
            maxZoom: 18,
            attribution: 'Map data &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, ' +
                'Imagery © <a href="https://www.mapbox.com/">Mapbox</a>',
            id: 'mapbox/streets-v11',
            tileSize: 512,
            zoomOffset: -1
        }).addTo(map);
    </script>
</body>

</html>"""

# %%
import json
  
# Opening JSON file
f = open('data/crc/crc_residential_sel.geojson')
  
# returns JSON object as 
# a dictionary
data = json.load(f)
print(data)
# Out:
# {'type': 'FeatureCollection', 'name': 'crc_residential_sel', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}}, 'features': [{'type': 'Feature', 'properties': {'Nazwa_MPZP': 'CYSTERSÃ“W', '_mean': 0.0, 'max_urbanity': 57, 'year': 2050, 'year_bs': 2050, 'year_zms': 2050, 'max_urbanity_bs': 62, 'max_urbanity_zms': 51}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[5032683.674251783, 3042682.5660446407], [5032678.387027113, 3042679.9479073673], [5032608.62288793, 3042696.7459941967], [5032521.555162612, 3042717.32924906], [5032521.120319117, 3042715.450812474], [5032508.913897149, 3042718.3559101224], [5032503.155821592, 3042724.504046124], [5032500.097382593, 3042734.517446669], [5032497.027715245, 3042744.58990796], [5032489.133077622, 3042772.0735749793], [5032488.378663657, 3042779.442287126], [5032489.85288122, 3042783.122132702], [5032486.912745012, 3042814.5902173566], [5032488.968683781, 3042848.704940505], [5032492.105862875, 3042857.981012
# ...

# %%
htmlwhole = """<!doctype html>
<html lang="en">

<head>

    <link rel="stylesheet" href="ol/ol.css" type="text/css">
    <!--importOL CSS-->
    <link rel="stylesheet" href="style.css" type="text/css">
    <link rel="stylesheet" href="https://unpkg.com/ol-layerswitcher@4.0.0/dist/ol-layerswitcher.css" />
    <!-- import OL JS -->
    <script src="ol/dist/ol.js"></script>
    <script src="https://unpkg.com/ol-layerswitcher@4.0.0"></script>
    <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/proj4js/2.5.0/proj4.js"></script>
    <title>OpenLayers example</title>
    <style>
        .map {
            width: 100%;
            height: 400px;
        }
    </style>
</head>

<body>
    <h1> My first map !</h1>
    <h2> This map displays Copenhagen !</h2>
    <div class="wrapper">
        <div id="roadMap" class="map">
            <h4>Road</h4>

        </div>
        <div class="half">
            <h4>Aerial</h4>
            <div id="aerialMap" class="map"></div>
        </div>
    </div>
    <!-- Pointer events polyfill for old browsers, see https://caniuse.com/#feat=pointer -->
    <script src="https://cdn.jsdelivr.net/npm/elm-pep@1.0.6/dist/elm-pep.js"></script>
    <script > var basemap = new ol.layer.Tile({
    title: 'Basemap',
    source: new ol.source.OSM()
});

var basemap1 = new ol.layer.Tile({
    title: 'Basemap',
    source: new ol.source.OSM()
});

var kommuner = new ol.layer.Vector({
    title: 'Kommuner',
    source: new ol.source.Vector({
        format: new ol.format.GeoJSON(),
        url: 'data/crc/crc_districts_re.geojson'
    }),
    style: new ol.style.Style({
        stroke: new ol.style.Stroke({
            color: 'rgba(255, 120, 0, 0.8)',
            width: 3
        }),
        fill: new ol.style.Fill({
            color: 'rgba(255, 120, 0, 0.1)'
        })
    })
});


var fill = new ol.style.Fill({
    color: 'rgba(255,255,255,0.4)'
});
var stroke = new ol.style.Stroke({
    color: '#3399CC',
    width: 1.25
});
var stroke2 = new ol.style.Stroke({
    color: 'yellow',
    width: 1.25
});
var style1 = [
    new ol.style.Style({
        fill: fill,
        stroke: stroke
    })
];
var style2 = [
    new ol.style.Style({

        fill: fill,
        stroke: stroke2
    })
];

var kommuner1 = new ol.layer.Vector({
    title: 'Kommuner',
    source: new ol.source.Vector({
        format: new ol.format.GeoJSON(),
        url: 'data/crc/crc_districts_re.geojson'
    }),
    style: function(feature, resolution) {

            const age = feature.get('_count_2');
            return age < 300 ? style1 : style2; // assuming these are created elsewhere
        }
        /*style: new ol.style.Style({
            stroke: new ol.style.Stroke({
                color: 'rgba(255, 120, 0, 0.8)',
                width: 3
            }),
            fill: new ol.style.Fill({
                color: 'rgba(255, 120, 0, 0.1)'
            })
        })*/
});

function transform(extent) {
    return ol.proj.transformExtent(extent, 'EPSG:4326', 'EPSG:3857');
}
const extents = {
    Copenhagen: transform([12.1, 55.55, 12.68, 55.82]),
{ "type": "Feature", "properties": { "Nazwa_MPZP": "OSIEDLE OFICERSKIE", "_mean": 67.084882553790237, "max_urbanity": 75, "year": 2050, "year_bs": 2050, "year_zms": 2050, "max_urbanity_bs": 80, "max_urbanity_zms": 70 }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ 5032266.722558680921793, 3043467.981557136401534 ], [ 5032258.016941335052252, 3043466.83784774877131 ], [ 5032247.485943214967847, 3043465.610632037743926 ], [ 5032238.801654238253832, 3043464.662547295447439 ], [ 5032235.587295237928629, 3043467.325982492882758 ], [ 5032233.44237055350095, 3043494.585879765916616 ], [ 5032232.239943346008658, 3043509.968291454482824 ], [ 5032231.331641075201333, 3043523.106611622031778 ], [ 5032228.901422062888741, 3043552.551181555725634 ], [ 5032228.368949158117175, 3043559.984430986456573 ], [ 5032227.833981216885149, 3043567.366671809460968 ], [ 5032226.814081210643053, 3043582.472885563969612 ], [ 5032247.329005331732333, 3043583.923145990353078 ], [ 5032266.027559810318053, 3043584.55203985562548 ], [ 5032267.842890424653888, 3043570.477422085590661 ], [ 5032268.838950960896909, 3043562.982600110583007 ], [ 5032269.813325261697173, 3043555.565510975196958 ], [ 5032271.48540510982275, 3043541.367978174705058 ], [ 5032273.174178865738213, 3043526.990695183165371 ], [ 5032274.820698460564017, 3043513.032331549096853 ], [ 5032276.43219380453229, 3043498.157305010594428 ], [ 5032269.07203771173954, 3043489.207037376705557 ], [ 5032267.642644740641117, 3043486.196118182502687 ], [ 5032267.291355292312801, 3043483.743081586435437 ], [ 5032267.086573923937976, 3043472.178244886454195 ], [ 5032266.722558680921793, 3043467.981557136401534 ] ] ] ] } }
]
}
 

var population = new ol.layer.Vector({
    title: 'Population',
    features: (new ol.format.GeoJSON()).readFeatures(crc_future, {
        dataProjection: 'EPSG:3035',
        featureProjection: 'EPSG:4326',
    }),
    style: function(feature, resolution) {
        const age = feature.get('max_urbanity');
        return age < 50 ? style1 : style2;
    }
});


// EPSG:4326
proj4.defs('EPSG:3035', '+proj=laea +lat_0=52 +lon_0=10 +x_0=4321000 +y_0=3210000 +ellps=GRS80 +units=m +no_defs');
ol.proj.proj4.register(proj4);
var myProjection = new ol.proj.Projection({
    code: 'EPSG:3035',
    extent: ol.proj.get('EPSG:3035').getExtent()
});
const view = new ol.View({
    center: ol.proj.fromLonLat([19.95949, 50.03767]),

    zoom: 13
});

const map1 = new ol.Map({
    target: 'roadMap',
    layers: [basemap, population],
    view: view,
    projection: myProjection,

    //projection: 'EPSG:3035'
});

const map2 = new ol.Map({
    target: 'aerialMap',
    layers: [basemap1, kommuner1],
    projection: myProjection,
    view: view
        //projection: 'EPSG:3035'
}); </script>
</body>

</html>"""

# %%
from IPython.core.display import display, HTML
htmlmap = HTML(htmlwhole)
html = htmlmap.data
with open('html3.html', 'w') as f:
    f.write(html)
# Out:
# C:\Users\NM12LQ\AppData\Local\Temp\ipykernel_12452\2144800750.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
